# %% [markdown]
# # 16.3 - Missing Values

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'useducation'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

used_df = pd.read_sql_query('select * from useducation',con=engine)

# no need for an open connection, 
# as we're only doing a single query
engine.dispose()

used_df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %% [markdown]
# ### Question 1

# %%
used_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492 entries, 0 to 1491
# Data columns (total 25 columns):
# PRIMARY_KEY                     1492 non-null object
# STATE                           1492 non-null object
# YEAR                            1492 non-null int64
# ENROLL                          1229 non-null float64
# TOTAL_REVENUE                   1280 non-null float64
# FEDERAL_REVENUE                 1280 non-null float64
# STATE_REVENUE                   1280 non-null float64
# LOCAL_REVENUE                   1280 non-null float64
# TOTAL_EXPENDITURE               1280 non-null float64
# INSTRUCTION_EXPENDITURE         1280 non-null float64
# SUPPORT_SERVICES_EXPENDITURE    1280 non-null float64
# OTHER_EXPENDITURE               1229 non-null float64
# CAPITAL_OUTLAY_EXPENDITURE      1280 non-null float64
# GRADES_PK_G                     1319 non-null float64
# GRADES_KG_G                     1360 non-null float64
# ...

# %%
used_df.isnull().sum()*100/used_df.isnull().count()
# Out:
# PRIMARY_KEY                      0.000000
# STATE                            0.000000
# YEAR                             0.000000
# ENROLL                          17.627346
# TOTAL_REVENUE                   14.209115
# FEDERAL_REVENUE                 14.209115
# STATE_REVENUE                   14.209115
# LOCAL_REVENUE                   14.209115
# TOTAL_EXPENDITURE               14.209115
# INSTRUCTION_EXPENDITURE         14.209115
# SUPPORT_SERVICES_EXPENDITURE    14.209115
# OTHER_EXPENDITURE               17.627346
# CAPITAL_OUTLAY_EXPENDITURE      14.209115
# GRADES_PK_G                     11.595174
# GRADES_KG_G                      8.847185
# GRADES_4_G                       8.780161
# GRADES_8_G                       8.780161
# GRADES_12_G                      8.780161
# GRADES_1_8_G                     8.780161
# GRADES_9_12_G                    8.780161
# GRADES_ALL_G                    11.595174
# AVG_MATH_4_SCORE                64.075067
# ...

# %% [markdown]
# ### Question 2
#
# If enrollment or revenue data is needed for certain analysis, it's probably best to discard observations that don't have data for them. State budgets developed to local education will vary greatly by size, local politics, and educational institutions in the area. An educated guess will likely be far off.
#
# For missing test scores, imputing a median value for that test probably makes the most sense.

# %%
used_df_2 = used_df.fillna(used_df.median())

# %% [markdown]
# ### Question 3

# %%
used_df_3 = pd.DataFrame(columns = used_df.columns)

for y in range(1992,2018):
    used_df_3 = used_df_3.append(used_df[used_df['YEAR']==y].fillna(used_df[used_df['YEAR']==y].median()))

# %% [markdown]
# ### Question 4

# %%
used_df_4 = used_df.interpolate()
used_df_4
# Out:
#                     PRIMARY_KEY                 STATE  YEAR     ENROLL  \
# 0                  1992_ALABAMA               ALABAMA  1992        NaN
# 1                   1992_ALASKA                ALASKA  1992        NaN
# 2                  1992_ARIZONA               ARIZONA  1992        NaN
# 3                 1992_ARKANSAS              ARKANSAS  1992        NaN
# 4               1992_CALIFORNIA            CALIFORNIA  1992        NaN
# 5                 1992_COLORADO              COLORADO  1992        NaN
# 6              1992_CONNECTICUT           CONNECTICUT  1992        NaN
# 7                 1992_DELAWARE              DELAWARE  1992        NaN
# 8     1992_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1992        NaN
# 9                  1992_FLORIDA               FLORIDA  1992        NaN
# 10                 1992_GEORGIA               GEORGIA  1992        NaN
# 11                  1992_HAWAII                HAWAII  1992        NaN
# ...

# %% [markdown]
# ### Question 5
#
# We'll compare a column with a lot of NaN values in our original data set.

# %%
print(used_df_2['AVG_MATH_4_SCORE'].describe(),'\n\n',used_df_3['AVG_MATH_4_SCORE'].describe(),'\n\n',used_df_4['AVG_MATH_4_SCORE'].describe())
# Out:
# count    1492.000000
# mean      236.351113
# std         6.236570
# min       187.134670
# 25%       237.238552
# 50%       237.238552
# 75%       237.238552
# max       253.420961
# Name: AVG_MATH_4_SCORE, dtype: float64
#
#  count    632.000000
# mean     234.337835
# std       10.051176
# min      187.134670
# 25%      227.719378
# 50%      236.867138
# 75%      241.590257
# max      253.420961
# Name: AVG_MATH_4_SCORE, dtype: float64
#
#  count    1492.000000
# mean      232.723472
# std         9.405215
# min       187.134670
# 25%       226.267129
# 50%       234.226904
# 75%       240.163315
# max       253.420961
# Name: AVG_MATH_4_SCORE, dtype: float64

# %% [markdown]
# The average doesn't vary drastically with the method we chose. However, the standard deviation is significantly different.
#
# Try one more:

# %%
print(used_df_2['AVG_READING_8_SCORE'].describe(),'\n\n',used_df_3['AVG_READING_8_SCORE'].describe(),'\n\n',used_df_4['AVG_READING_8_SCORE'].describe())
# Out:
# count    1492.000000
# mean      264.560382
# std         3.979401
# min       236.379102
# 25%       265.010912
# 50%       265.010912
# 75%       265.010912
# max       280.499130
# Name: AVG_READING_8_SCORE, dtype: float64
#
#  count    632.000000
# mean     263.756013
# std        6.068944
# min      236.379102
# 25%      261.117268
# 50%      264.532051
# 75%      267.451963
# max      280.499130
# Name: AVG_READING_8_SCORE, dtype: float64
#
#  count    1491.000000
# mean      263.267799
# std         4.978792
# min       236.379102
# 25%       260.490023
# 50%       262.617766
# 75%       266.849675
# max       280.499130
# Name: AVG_READING_8_SCORE, dtype: float64

# %% [markdown]
# Similar story. I'm not sure if this is a result of modifying a variable with fairly small variance, or if this is indicative of differences in methods.
