# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import keras
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers import LSTM, Input, TimeDistributed
from keras.models import Model
from keras.optimizers import RMSprop
from keras import backend as K

import warnings

warnings.filterwarnings('ignore')

X = np.load('../Module 26 - Unsupervised Learning/kmnist-train-imgs.npz')['arr_0']
y = np.load('../Module 26 - Unsupervised Learning/kmnist-train-labels.npz')['arr_0']
# Out:
# Using TensorFlow backend.

# %%
plt.figure(figsize=(20,12))

plt.subplot(2,4,1)
plt.imshow(X[0].reshape(28,28))

plt.subplot(2,4,2)
plt.imshow(X[1].reshape(28,28))

plt.subplot(2,4,3)
plt.imshow(X[2].reshape(28,28))

plt.subplot(2,4,4)
plt.imshow(X[3].reshape(28,28))

plt.subplot(2,4,5)
plt.imshow(X[4].reshape(28,28))

plt.subplot(2,4,6)
plt.imshow(X[5].reshape(28,28))

plt.subplot(2,4,7)
plt.imshow(X[6].reshape(28,28))

plt.subplot(2,4,8)
plt.imshow(X[7].reshape(28,28))

plt.show()

# %%
pd.Series(y).value_counts()
# Out:
# 9    6000
# 8    6000
# 7    6000
# 6    6000
# 5    6000
# 4    6000
# 3    6000
# 2    6000
# 1    6000
# 0    6000
# dtype: int64

# %%
X = X.reshape(60000,784)
y = to_categorical(y, 10)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=17)

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dropout(0.1))
model.add(Dense(10, activation='softmax'))

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])


model.fit(X_train, y_train,
         batch_size=128,
         epochs=10,
         verbose=1,
         validation_data=(X_test, y_test))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 2s 44us/step - loss: 2.1643 - accuracy: 0.8571 - val_loss: 2.0525 - val_accuracy: 0.8638
# Epoch 2/10
# 48000/48000 [==============================] - 2s 32us/step - loss: 1.8037 - accuracy: 0.8803 - val_loss: 1.6944 - val_accuracy: 0.8876
# Epoch 3/10
# 48000/48000 [==============================] - 2s 38us/step - loss: 1.5477 - accuracy: 0.8974 - val_loss: 1.2800 - val_accuracy: 0.9148
# Epoch 4/10
# 48000/48000 [==============================] - 2s 34us/step - loss: 1.2799 - accuracy: 0.9152 - val_loss: 1.2070 - val_accuracy: 0.9199
# Epoch 5/10
# 48000/48000 [==============================] - 2s 34us/step - loss: 1.2062 - accuracy: 0.9201 - val_loss: 1.1709 - val_accuracy: 0.9222
# Epoch 6/10
# 48000/48000 [==============================] - 2s 34us/step - loss: 1.1839 - accuracy: 0.9217 - val_loss: 1.1312 - val_accuracy: 0.9251
# Epoch 7/10
# 48000/48000 [==============================] - 2s 35us/step - loss: 1.1576 - accuracy: 0.9235 - val_loss: 1.1154 - val_accuracy: 0.9262
# Epoch 8/10
# 48000/48000 [==============================] - 2s 31us/step - loss: 1.1207 - accuracy: 0.9261 - val_loss: 1.1077 - val_accuracy: 0.9270
# Epoch 9/10
# 48000/48000 [==============================] - 1s 28us/step - loss: 1.1271 - accuracy: 0.9258 - val_loss: 1.0579 - val_accuracy: 0.9301
# Epoch 10/10
# 48000/48000 [==============================] - 1s 28us/step - loss: 1.1212 - accuracy: 0.9261 - val_loss: 1.0527 - val_accuracy: 0.9303

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(10, activation='softmax'))

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])


model.fit(X_train, y_train,
         batch_size=128,
         epochs=10,
         verbose=1,
         validation_data=(X_test, y_test))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 2s 42us/step - loss: 1.8222 - accuracy: 0.8757 - val_loss: 1.1026 - val_accuracy: 0.9227
# Epoch 2/10
# 48000/48000 [==============================] - 2s 33us/step - loss: 1.0615 - accuracy: 0.9264 - val_loss: 0.8060 - val_accuracy: 0.9438
# Epoch 3/10
# 48000/48000 [==============================] - 2s 34us/step - loss: 0.9003 - accuracy: 0.9376 - val_loss: 0.7149 - val_accuracy: 0.9505
# Epoch 4/10
# 48000/48000 [==============================] - 2s 34us/step - loss: 0.8277 - accuracy: 0.9427 - val_loss: 0.7213 - val_accuracy: 0.9498
# Epoch 5/10
# 48000/48000 [==============================] - 2s 33us/step - loss: 0.8088 - accuracy: 0.9444 - val_loss: 0.7228 - val_accuracy: 0.9500
# Epoch 6/10
# 48000/48000 [==============================] - 2s 33us/step - loss: 0.8022 - accuracy: 0.9449 - val_loss: 0.6958 - val_accuracy: 0.9520
# Epoch 7/10
# 48000/48000 [==============================] - 2s 33us/step - loss: 0.7536 - accuracy: 0.9480 - val_loss: 0.6354 - val_accuracy: 0.9561
# Epoch 8/10
# 48000/48000 [==============================] - 2s 33us/step - loss: 0.7167 - accuracy: 0.9502 - val_loss: 0.6126 - val_accuracy: 0.9567
# Epoch 9/10
# 48000/48000 [==============================] - 2s 35us/step - loss: 0.6370 - accuracy: 0.9541 - val_loss: 0.4427 - val_accuracy: 0.9660
# Epoch 10/10
# 48000/48000 [==============================] - 2s 39us/step - loss: 0.3962 - accuracy: 0.9588 - val_loss: 0.2556 - val_accuracy: 0.9627

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(10, activation='softmax'))

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])


model.fit(X_train, y_train,
         batch_size=128,
         epochs=10,
         verbose=1,
         validation_data=(X_test, y_test))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 2s 45us/step - loss: 1.4318 - accuracy: 0.8881 - val_loss: 0.4479 - val_accuracy: 0.9432
# Epoch 2/10
# 48000/48000 [==============================] - 2s 33us/step - loss: 0.2269 - accuracy: 0.9439 - val_loss: 0.1156 - val_accuracy: 0.9632
# Epoch 3/10
# 48000/48000 [==============================] - 2s 32us/step - loss: 0.1160 - accuracy: 0.9649 - val_loss: 0.0782 - val_accuracy: 0.9758
# Epoch 4/10
# 48000/48000 [==============================] - 2s 35us/step - loss: 0.0898 - accuracy: 0.9725 - val_loss: 0.0655 - val_accuracy: 0.9793
# Epoch 5/10
# 48000/48000 [==============================] - 2s 35us/step - loss: 0.0785 - accuracy: 0.9758 - val_loss: 0.0601 - val_accuracy: 0.9810
# Epoch 6/10
# 48000/48000 [==============================] - 2s 33us/step - loss: 0.0697 - accuracy: 0.9784 - val_loss: 0.0567 - val_accuracy: 0.9823
# Epoch 7/10
# 48000/48000 [==============================] - 2s 34us/step - loss: 0.0646 - accuracy: 0.9797 - val_loss: 0.0545 - val_accuracy: 0.9831
# Epoch 8/10
# 48000/48000 [==============================] - 2s 35us/step - loss: 0.0606 - accuracy: 0.9812 - val_loss: 0.0513 - val_accuracy: 0.9843
# Epoch 9/10
# 48000/48000 [==============================] - 2s 36us/step - loss: 0.0579 - accuracy: 0.9821 - val_loss: 0.0512 - val_accuracy: 0.9845
# Epoch 10/10
# 48000/48000 [==============================] - 2s 39us/step - loss: 0.0542 - accuracy: 0.9832 - val_loss: 0.0506 - val_accuracy: 0.9853

# %%
X_train_2d = X_train.reshape(48000,28,28)
X_test_2d = X_test.reshape(12000,28,28)


model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(28,28)))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])


model.fit(X_train_2d, y_train,
         batch_size=128,
         epochs=10,
         verbose=1,
         validation_data=(X_test_2d, y_test)
         )
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 11s 222us/step - loss: 0.4083 - accuracy: 0.9245 - val_loss: 0.0908 - val_accuracy: 0.9689
# Epoch 2/10
# 48000/48000 [==============================] - 10s 199us/step - loss: 0.0940 - accuracy: 0.9674 - val_loss: 0.0646 - val_accuracy: 0.9781
# Epoch 3/10
# 48000/48000 [==============================] - 9s 182us/step - loss: 0.0746 - accuracy: 0.9745 - val_loss: 0.0625 - val_accuracy: 0.9789
# Epoch 4/10
# 48000/48000 [==============================] - 9s 189us/step - loss: 0.0664 - accuracy: 0.9774 - val_loss: 0.0554 - val_accuracy: 0.9821
# Epoch 5/10
# 48000/48000 [==============================] - 9s 188us/step - loss: 0.0615 - accuracy: 0.9792 - val_loss: 0.0562 - val_accuracy: 0.9813
# Epoch 6/10
# 48000/48000 [==============================] - 10s 200us/step - loss: 0.0579 - accuracy: 0.9805 - val_loss: 0.0524 - val_accuracy: 0.9828
# Epoch 7/10
# 48000/48000 [==============================] - 10s 202us/step - loss: 0.0550 - accuracy: 0.9817 - val_loss: 0.0523 - val_accuracy: 0.9829
# Epoch 8/10
# 48000/48000 [==============================] - 9s 194us/step - loss: 0.0529 - accuracy: 0.9823 - val_loss: 0.0483 - val_accuracy: 0.9845
# Epoch 9/10
# 48000/48000 [==============================] - 10s 199us/step - loss: 0.0509 - accuracy: 0.9827 - val_loss: 0.0487 - val_accuracy: 0.9842
# Epoch 10/10
# 48000/48000 [==============================] - 9s 187us/step - loss: 0.0499 - accuracy: 0.9833 - val_loss: 0.0470 - val_accuracy: 0.9847

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(28,28)))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])


model.fit(X_train_2d, y_train,
         batch_size=128,
         epochs=10,
         verbose=1,
         validation_data=(X_test_2d, y_test)
         )
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 7s 150us/step - loss: 0.8406 - accuracy: 0.9096 - val_loss: 0.1167 - val_accuracy: 0.9595
# Epoch 2/10
# 48000/48000 [==============================] - 6s 133us/step - loss: 0.1120 - accuracy: 0.9622 - val_loss: 0.0719 - val_accuracy: 0.9756
# Epoch 3/10
# 48000/48000 [==============================] - 8s 168us/step - loss: 0.0789 - accuracy: 0.9733 - val_loss: 0.0619 - val_accuracy: 0.9792
# Epoch 4/10
# 48000/48000 [==============================] - 7s 153us/step - loss: 0.0681 - accuracy: 0.9770 - val_loss: 0.0572 - val_accuracy: 0.9807
# Epoch 5/10
# 48000/48000 [==============================] - 7s 153us/step - loss: 0.0615 - accuracy: 0.9790 - val_loss: 0.0540 - val_accuracy: 0.9822
# Epoch 6/10
# 48000/48000 [==============================] - 7s 143us/step - loss: 0.0577 - accuracy: 0.9805 - val_loss: 0.0525 - val_accuracy: 0.9826
# Epoch 7/10
# 48000/48000 [==============================] - 7s 151us/step - loss: 0.0545 - accuracy: 0.9818 - val_loss: 0.0503 - val_accuracy: 0.9833
# Epoch 8/10
# 48000/48000 [==============================] - 8s 177us/step - loss: 0.0517 - accuracy: 0.9827 - val_loss: 0.0504 - val_accuracy: 0.9834
# Epoch 9/10
# 48000/48000 [==============================] - 7s 136us/step - loss: 0.0497 - accuracy: 0.9833 - val_loss: 0.0501 - val_accuracy: 0.9832
# Epoch 10/10
# 48000/48000 [==============================] - 6s 133us/step - loss: 0.0485 - accuracy: 0.9838 - val_loss: 0.0477 - val_accuracy: 0.9840

# %%
X_train_cnn = X_train.astype('float32')
X_test_cnn = X_test.astype('float32')

X_train_cnn /= 255
X_test_cnn /= 255

X_train_cnn = X_train_cnn.reshape(48000,28,28,1)
X_test_cnn = X_test_cnn.reshape(12000,28,28,1)

# %%
# Out:
# (48000, 784)

# %%
model = Sequential()
# First convolutional layer, note the specification of shape
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(28,28,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.compile(loss='binary_crossentropy',
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(X_train_cnn, y_train,
          batch_size=128,
          epochs=10,
          verbose=1,
          validation_data=(X_test_cnn, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 95s 2ms/step - loss: 0.1226 - accuracy: 0.9566 - val_loss: 0.0549 - val_accuracy: 0.9814
# Epoch 2/10
# 48000/48000 [==============================] - 95s 2ms/step - loss: 0.0615 - accuracy: 0.9786 - val_loss: 0.0315 - val_accuracy: 0.9895
# Epoch 3/10
# 48000/48000 [==============================] - 91s 2ms/step - loss: 0.0420 - accuracy: 0.9857 - val_loss: 0.0226 - val_accuracy: 0.9922
# Epoch 4/10
# 48000/48000 [==============================] - 86s 2ms/step - loss: 0.0338 - accuracy: 0.9883 - val_loss: 0.0195 - val_accuracy: 0.9934
# Epoch 5/10
# 48000/48000 [==============================] - 84s 2ms/step - loss: 0.0287 - accuracy: 0.9902 - val_loss: 0.0170 - val_accuracy: 0.9942
# Epoch 6/10
# 48000/48000 [==============================] - 102s 2ms/step - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.0152 - val_accuracy: 0.9950
# Epoch 7/10
# 48000/48000 [==============================] - 97s 2ms/step - loss: 0.0220 - accuracy: 0.9926 - val_loss: 0.0143 - val_accuracy: 0.9952
# Epoch 8/10
# 48000/48000 [==============================] - 87s 2ms/step - loss: 0.0201 - accuracy: 0.9931 - val_loss: 0.0144 - val_accuracy: 0.9952
# Epoch 9/10
# 48000/48000 [==============================] - 97s 2ms/step - loss: 0.0183 - accuracy: 0.9935 - val_loss: 0.0132 - val_accuracy: 0.9957
# Epoch 10/10
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9942

# %%
# Out:
# (48000, 10)
